# %% [markdown]
# <a href="https://colab.research.google.com/github/mmrbulbul/TensorFlow/blob/master/TensorFlow_Hello_World.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## This is a simple tensorFlow model to introduction It tries to figure out a simple equation like  y= 2*x-1

# %%
#impot modules 
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
#create model 
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd',loss='mean_squared_error')
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0728 14:28:30.430944 140167168628608 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
#dataset
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
#fit the mmodel 
model.fit(xs,ys,epochs= 400)
# Out:
# Epoch 1/400
# 6/6 [==============================] - 0s 13ms/sample - loss: 14.6944
# Epoch 2/400
# 6/6 [==============================] - 0s 728us/sample - loss: 11.7993
# Epoch 3/400
# 6/6 [==============================] - 0s 418us/sample - loss: 9.5168
# Epoch 4/400
# 6/6 [==============================] - 0s 248us/sample - loss: 7.7162
# Epoch 5/400
# 6/6 [==============================] - 0s 237us/sample - loss: 6.2948
# Epoch 6/400
# 6/6 [==============================] - 0s 359us/sample - loss: 5.1720
# Epoch 7/400
# 6/6 [==============================] - 0s 258us/sample - loss: 4.2841
# Epoch 8/400
# 6/6 [==============================] - 0s 317us/sample - loss: 3.5811
# Epoch 9/400
# 6/6 [==============================] - 0s 256us/sample - loss: 3.0237
# Epoch 10/400
# 6/6 [==============================] - 0s 351us/sample - loss: 2.5809
# Epoch 11/400
# 6/6 [==============================] - 0s 249us/sample - loss: 2.2284
# Epoch 12/400
# ...

# %%
print(model.predict([10]))
# Out:
# [[18.948345]]
